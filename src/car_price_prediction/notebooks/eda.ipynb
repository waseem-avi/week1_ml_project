# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/car_data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# Selling_price is are target feature
# FuelType, Owner,  Sellertype and Transmission are our category features

# %%
print(df["Seller_Type"].unique())
# Out:
# ['Dealer' 'Individual']

# %%
print(df["Fuel_Type"].unique())
print(df['Owner'].unique())
print(df['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# [0 1 3]
# ['Manual' 'Automatic']

# %%
# check for missing or null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# The data seems to contain no null values

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# removing car name as a feature
final_df = df[[ 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_df['Current_Year'] = 2024

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2024
# 1       Manual      0          2024
# 2       Manual      0          2024
# 3       Manual      0          2024
# 4       Manual      0          2024

# %%
final_df['Age'] = final_df['Current_Year'] - final_df['Year']
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  Age
# 0       Manual      0          2024   10
# 1       Manual      0          2024   11
# 2       Manual      0          2024    7
# 3       Manual      0          2024   13
# 4       Manual      0          2024   10

# %%
final_df.drop(['Year', 'Current_Year'] , axis=1, inplace=True)
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0   10
# 1       Manual      0   11
# 2       Manual      0    7
# 3       Manual      0   13
# 4       Manual      0   10

# %%
final_df = pd.get_dummies(final_df, drop_first=True)
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0   10             False
# 1           4.75           9.54       43000      0   11              True
# 2           7.25           9.85        6900      0    7             False
# 3           2.85           4.15        5200      0   13             False
# 4           4.60           6.87       42450      0   10              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
final_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Age                         -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                              Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(final_df)

# %%
correl = final_df.corr()
top_corr_features = correl.index
plt.figure(figsize=(20, 20))
hm = sns.heatmap(final_df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
X = final_df.iloc[:, 1:]
y = final_df.iloc[:, 0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000      0   10             False              True
# 1           9.54       43000      0   11              True             False
# 2           9.85        6900      0    7             False              True
# 3           4.15        5200      0   13             False              True
# 4           6.87       42450      0   10              True             False
#
#    Seller_Type_Individual  Transmission_Manual
# 0                   False                 True
# 1                   False                 True
# 2                   False                 True
# 3                   False                 True
# 4                   False                 True

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
# feature importance 
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.05594486e-01 3.93777578e-02 3.13584309e-04 7.85269682e-02
#  2.08962668e-01 1.07921040e-02 1.28321414e-01 1.28111017e-01]

# %%
# plot graph of feature importance
feat_imp = pd.Series(model.feature_importances_, index = X.columns)
feat_imp.nlargest(5).plot(kind = 'barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size=0.2)

# %%
X_test.shape
# Out:
# (61, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
# hyper-parameters
import numpy as np 
n_estimators =[int(x) for x in np.linspace(start = 100 , stop = 1200 , num = 12 )]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
# number of feats to consider at every split
max_feats = ['log2', 'sqrt']

# %%
# max number of levels in tree 
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

# %%
#min number of samples required to split a node
min_samples_split = [2, 5, 10 , 15, 100]

# %%
# min number of samples required at each leaf node 
min_samples_leaf = [1, 2, 5, 10]

# %%
from sklearn.model_selection import RandomizedSearchCV
# create random grid 
random_grid = {'n_estimators':n_estimators, 
               'max_features':max_feats,
               'max_depth':max_depth,
               'min_samples_leaf':min_samples_leaf,
               'min_samples_split':min_samples_split               
               }
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['log2', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_leaf': [1, 2, 5, 10], 'min_samples_split': [2, 5, 10, 15, 100]}

# %%
rf_random = RandomizedSearchCV(estimator= rf , param_distributions=random_grid, scoring='neg_mean_squared_error', n_iter = 11, cv = 5, verbose = 2 , random_state = 42, n_jobs = 1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.7s
# ...

# %%
pred = rf_random.predict(X_test)
pred
# Out:
# array([ 0.68429, 15.86021,  5.2802 , 11.42498,  0.77482,  7.05001,
#         4.77925, 20.86803,  0.59719,  6.22845,  5.4305 ,  4.05831,
#         3.0872 , 13.52206,  3.63866,  0.87348,  8.1333 ,  3.29745,
#         0.6273 ,  4.42918,  0.59603, 13.03113,  4.90065,  2.78526,
#         6.86477,  1.41758,  4.4284 ,  0.65205,  3.36073,  0.51352,
#         8.25075,  3.92134,  3.17735,  0.47468,  2.56917,  8.0214 ,
#         3.25535,  4.08907,  9.635  ,  1.00317,  1.0149 ,  1.1115 ,
#        10.1119 ,  0.5645 ,  5.84521,  5.07503,  3.0605 ,  4.99375,
#        12.64114,  0.89841,  4.3088 ,  7.35619,  1.00753,  5.31227,
#         6.79821,  0.65871,  5.27092,  9.18364,  0.24917,  9.12984,
#         0.86566])

# %%
sns.displot(y_test-pred)

# %%
plt.scatter(y_test, pred)

# %%
import pickle 
file = open ('../datafiles/random_forest_regression_model.pkl' , 'wb')
pickle.dump(rf_random, file)
